# %%
import bs4; print( 'bs4 ' + bs4.__version__)
from bs4 import BeautifulSoup, SoupStrainer;

import re; print('re ' + re.__version__)

import requests; print('requests ' + requests.__version__)
import ast;
import pandas as pd; print( 'pandas ' + pd.__version__)
# Out:
# bs4 4.6.3
# re 2.2.1
# requests 2.19.1
# pandas 0.22.0

# %%
URL_LIST_OF_ALL = 'https://en.wikipedia.org/wiki/List_of_current_members_of_the_United_States_House_of_Representatives'

LOCAL_RAW_LIST_FILE_PATH = 'data/raw_wikipedia_list.html'
SAVED_CSV_FILE_PATH = 'data/representatives_list_raw.csv'

# %%
def get_text_from_local():
    with open(LOCAL_RAW_LIST_FILE_PATH) as f:
        return f

def get_text_from_url_and_save(url):
    text = requests.get(url).text
    with open(LOCAL_RAW_LIST_FILE_PATH, 'w') as f:
        f.write(text)
    return text


def get_html_list_of_representatives():
    # first try to get from local
    try:
        return get_text_from_local()
    # otherwise pull from URL
    except:
        return get_text_from_url_and_save(URL_LIST_OF_ALL)
text = get_html_list_of_representatives()

# %%
# Helper functions


def get_nth_cell(row, num):
    #print('td:nth-of-type({})'.format(num))
    return row.find_all('td')[num]

def get_link_element(cell):
    link_row = get_nth_cell(cell, 1)
    return link_row.find_all(name='a')[-1]

def split_by_br(cell):
    split_by = '--BRRR--'
    cell_string = str(cell).replace('<br/>', split_by)
    b = BeautifulSoup(cell_string, 'lxml')
    text = b.text
    return [line.strip() for line in text.split(split_by)]

# %%
def get_district(row):
    return get_nth_cell(row, 0).text.strip()

def get_name(row):
    return get_link_element(row).text.strip()
def get_link(row):
    return get_link_element(row).attrs['href']

def get_party(row):
    return get_nth_cell(row, 3).text.strip()

def get_experience(row):
    cell = get_nth_cell(row, -5)
    return split_by_br(cell)

def get_education(row):
    cell = get_nth_cell(row, -4)
    educations_raw = split_by_br(cell)
    educations_glued = []
    for experience_raw in educations_raw:
        match = re.match('^\(.*\)$', experience_raw)
        if not match:
            # this is as expected
            educations_glued.append(experience_raw)
        else:
            # this shouldn't be by itself and should be added to the previous school mentioned - example (BA) or (MS)
            educations_glued[-1] = educations_glued[-1] + " " + experience_raw
    return educations_glued

def is_vacant(row):
    vacant_row = get_nth_cell(row, 1).text.strip()
    return vacant_row ==   'Vacant'

def get_all_links_and_info(text):
    b = BeautifulSoup(text, 'lxml')
    table = b.find(id = 'votingmembers')
    rows = table.findAll(name='tr')
    output = {
        'district': [],
        'name': [],
        'link': [],
        'party': [],
        'experience': [],
        'education': [],
    }
    i = 0
    for row in rows[1:]:
        i+=1
        if is_vacant(row):
            continue
        output['district'].append(get_district(row))
        output['name'].append(get_name(row))
        output['link'].append(get_link(row))
        output['party'].append(get_party(row))
        output['experience'].append(get_experience(row))
        output['education'].append(get_education(row))
    return pd.DataFrame(output)
all_info = get_all_links_and_info(text)
all_info
# Out:
#              district                                          education  \
# 0           Alabama 1  [Duke University (BA), University of Alabama (...
# 1           Alabama 2  [New York University (BM), Samford University ...
# 2           Alabama 3  [Jacksonville State University (BA, MPA), Birm...
# 3           Alabama 4  [University of North Alabama, Birmingham–South...
# 4           Alabama 5  [Duke University (BA), University of Alabama (...
# 5           Alabama 6                       [University of Alabama (BS)]
# 6           Alabama 7  [Princeton University (BA), St Hilda's College...
# 7     Alaska at large  [Yuba College, California State University, Ch...
# 8           Arizona 1              [Lewis University, DePaul University]
# 9           Arizona 2  [United States Air Force Academy (BS), Harvard...
# 10          Arizona 3                       [University of Arizona (BA)]
# 11          Arizona 4                   [Creighton University (BS, DDS)]
# 12          Arizona 5  [Brigham Young University (BA), University of ...
# 13          Arizona 6        [Arizona State University, Tempe (BS, MBA)]
# 14          Arizona 7                          [Harvard University (BA)]
# 15          Arizona 8             [University of Wisconsin–Madison (BA)]
# 16          Arizona 9  [Brigham Young University (BA), Arizona State ...
# 17         Arkansas 1                   [Arkansas State University (BS)]
# 18         Arkansas 2                       [Vanderbilt University (BS)]
# 19         Arkansas 3                    [Arkansas Tech University (BA)]
# 20         Arkansas 4  [University of Arkansas (BS), Yale University ...
# 21       California 1  [Butte College, California Polytechnic State U...
# 22       California 2  [University of California, Santa Barbara (BA),...
# 23       California 3  [University of California, Berkeley (BA), Harv...
# 24       California 4       [University of California, Los Angeles (BA)]
# 25       California 5  [Napa Valley College, California State Univers...
# 26       California 6          [University of California, Berkeley (BA)]
# 27       California 7        [University of California, Irvine (BS, MD)]
# 28       California 8  [Southern Connecticut State University (BS), C...
# 29       California 9  [United States Military Academy, University of...
# ..                ...                                                ...
# 400        Virginia 3     [Harvard University (BA), Boston College (JD)]
# 401        Virginia 4  [American University (BA), University of Virgi...
# 402        Virginia 5                  [University of Richmond (BA, JD)]
# 403        Virginia 6  [Bates College (BA), Washington and Lee Univer...
# 404        Virginia 7  [Hope College (BA), Princeton Theological Semi...
# 405        Virginia 8                            [Williams College (BA)]
# 406        Virginia 9  [Emory and Henry College (BA), Washington and ...
# 407       Virginia 10  [Middlebury College (BA), Georgetown Universit...
# 408       Virginia 11  [Maryknoll College (BA), Harvard University (M...
# 409      Washington 1  [Reed College (BS), University of Washington (...
# 410      Washington 2  [Pacific Lutheran University (BA), University ...
# 411      Washington 3  [Bellevue College, University of Washington (BA)]
# 412      Washington 4                 [Washington State University (BS)]
# 413      Washington 5  [Pensacola Christian College (BA), University ...
# 414      Washington 6  [Princeton University (BA), University of Oxfo...
# 415      Washington 7  [Georgetown University (BA), Northwestern Univ...
# 416      Washington 8                     [Concordia University, Oregon]
# 417      Washington 9  [Western Washington University, Fordham Univer...
# 418     Washington 10  [Evergreen State College (BA), Portland State ...
# 419   West Virginia 1                           [Purdue University (BS)]
# 420   West Virginia 2                           [Dartmouth College (BA)]
# 421       Wisconsin 1                            [Miami University (BA)]
# 422       Wisconsin 2             [University of Wisconsin–Madison (BA)]
# 423       Wisconsin 3  [Harvard University (BA), London School of Eco...
# 424       Wisconsin 4                        [Marquette University (BA)]
# 425       Wisconsin 5  [Stanford University (BA), University of Wisco...
# 426       Wisconsin 6         [University of Wisconsin–Madison (BA, JD)]
# 427       Wisconsin 7  [Saint Mary's University of Minnesota (BA), Wi...
# 428       Wisconsin 8  [Princeton University (BA), National Intellige...
# 429  Wyoming at large  [Colorado College (BA), University of Chicago ...
#
#                                             experience  \
# 0    [Alabama Senate, Alabama State Board of Educat...
# 1                            [Montgomery City Council]
# 2    [Calhoun County Commissioner, Alabama House of...
# 3                         [Haleyville Municipal Judge]
# 4    [Alabama House of Representatives, Madison Cou...
# 5                                     [Policy analyst]
# 6                                           [Attorney]
# 7    [Alaska Senate, Ship captain, Mayor of Fort Yu...
# 8                                     [Arizona Senate]
# 9                                       [USAF Colonel]
# 10                  [Pima County Board of Supervisors]
# 11   [President of the Northern Arizona Dental Soci...
# 12                                    [Arizona Senate]
# 13   [Arizona House of Representatives, Arizona Boa...
# 14                  [Arizona House of Representatives]
# 15   [Arizona House of Representatives, Arizona Sen...
# 16   [Arizona Senate, Arizona House of Representati...
# 17                          [Broadcaster, businessman]
# 18                                       [Businessman]
# 19                         [Mayor of Rogers, Arkansas]
# 20                 [Arkansas House of Representatives]
# 21   [California State Senate, California State Ass...
# 22                         [California State Assembly]
# 23   [United States Deputy Secretary of the Interio...
# 24      [California Senate, California State Assembly]
# 25                           [California State Senate]
# 26               [Sacramento, California City Council]
# 27   [Chief Medical Officer of Sacramento County, C...
# 28                         [California State Assembly]
# 29                             [Engineering executive]
# ..                                                 ...
# 400     [Virginia Senate, Virginia House of Delegates]
# 401     [Virginia Senate, Virginia House of Delegates]
# 402                                  [Virginia Senate]
# 403                           [Private legal practice]
# 404    [Economics professor at Randolph–Macon College]
# 405  [U.S. Ambassador to Switzerland and Liechtenst...
# 406  [Majority Leader of the Virginia House of Dele...
# 407                      [Virginia House of Delegates]
# 408        [Fairfax County Board of Supervisors Chair]
# 409        [Washington Department of Revenue Director]
# 410                         [Snohomish County Council]
# 411              [Washington House of Representatives]
# 412              [Washington House of Representatives]
# 413              [Washington House of Representatives]
# 414                          [Washington State Senate]
# 415                          [Washington State Senate]
# 416                              [King County Sheriff]
# 417                          [Washington State Senate]
# 418              [Washington House of Representatives]
# 419    [West Virginia House of Delegates, businessman]
# 420                                  [Maryland Senate]
# 421                             [Legislative Director]
# 422                         [Wisconsin State Assembly]
# 423                                [County Prosecutor]
# 424  [Wisconsin State Senate, Wisconsin State Assem...
# 425  [Wisconsin State Senate, Wisconsin State Assem...
# 426       [Wisconsin Senate, Wisconsin State Assembly]
# 427                 [Ashland County District Attorney]
# 428                                [Political advisor]
# 429  [Principal Deputy Assistant Secretary of State...
#
#                                             link                    name  \
# 0                            /wiki/Bradley_Byrne           Bradley Byrne
# 1                              /wiki/Martha_Roby             Martha Roby
# 2         /wiki/Mike_Rogers_(Alabama_politician)             Mike Rogers
# 3                          /wiki/Robert_Aderholt         Robert Aderholt
# 4                                /wiki/Mo_Brooks               Mo Brooks
# 5                 /wiki/Gary_Palmer_(politician)             Gary Palmer
# 6                             /wiki/Terri_Sewell            Terri Sewell
# 7                                /wiki/Don_Young               Don Young
# 8                         /wiki/Tom_O%27Halleran          Tom O'Halleran
# 9                           /wiki/Martha_McSally          Martha McSally
# 10                      /wiki/Ra%C3%BAl_Grijalva           Raúl Grijalva
# 11                              /wiki/Paul_Gosar              Paul Gosar
# 12                              /wiki/Andy_Biggs              Andy Biggs
# 13                        /wiki/David_Schweikert        David Schweikert
# 14                           /wiki/Ruben_Gallego           Ruben Gallego
# 15                            /wiki/Debbie_Lesko            Debbie Lesko
# 16                          /wiki/Kyrsten_Sinema          Kyrsten Sinema
# 17              /wiki/Rick_Crawford_(politician)           Rick Crawford
# 18                /wiki/French_Hill_(politician)             French Hill
# 19                            /wiki/Steve_Womack            Steve Womack
# 20                         /wiki/Bruce_Westerman         Bruce Westerman
# 21                            /wiki/Doug_LaMalfa            Doug LaMalfa
# 22                           /wiki/Jared_Huffman           Jared Huffman
# 23                          /wiki/John_Garamendi          John Garamendi
# 24                          /wiki/Tom_McClintock          Tom McClintock
# 25   /wiki/Mike_Thompson_(California_politician)           Mike Thompson
# 26                            /wiki/Doris_Matsui            Doris Matsui
# 27                                /wiki/Ami_Bera                Ami Bera
# 28                  /wiki/Paul_Cook_(politician)               Paul Cook
# 29                          /wiki/Jerry_McNerney          Jerry McNerney
# ..                                           ...                     ...
# 400               /wiki/Bobby_Scott_(politician)             Bobby Scott
# 401                        /wiki/Donald_McEachin         Donald McEachin
# 402                        /wiki/Tom_Garrett_Jr.         Tom Garrett Jr.
# 403                          /wiki/Bob_Goodlatte           Bob Goodlatte
# 404                              /wiki/Dave_Brat               Dave Brat
# 405                              /wiki/Don_Beyer               Don Beyer
# 406                        /wiki/Morgan_Griffith         Morgan Griffith
# 407                       /wiki/Barbara_Comstock        Barbara Comstock
# 408                         /wiki/Gerry_Connolly          Gerry Connolly
# 409                          /wiki/Suzan_DelBene           Suzan DelBene
# 410                            /wiki/Rick_Larsen             Rick Larsen
# 411                  /wiki/Jaime_Herrera_Beutler   Jaime Herrera Beutler
# 412                           /wiki/Dan_Newhouse            Dan Newhouse
# 413                 /wiki/Cathy_McMorris_Rodgers  Cathy McMorris Rodgers
# 414                           /wiki/Derek_Kilmer            Derek Kilmer
# 415                        /wiki/Pramila_Jayapal         Pramila Jayapal
# 416                          /wiki/Dave_Reichert           Dave Reichert
# 417                /wiki/Adam_Smith_(politician)              Adam Smith
# 418                            /wiki/Dennis_Heck             Dennis Heck
# 419                         /wiki/David_McKinley          David McKinley
# 420                            /wiki/Alex_Mooney             Alex Mooney
# 421                              /wiki/Paul_Ryan               Paul Ryan
# 422                             /wiki/Mark_Pocan              Mark Pocan
# 423                               /wiki/Ron_Kind                Ron Kind
# 424                             /wiki/Gwen_Moore              Gwen Moore
# 425                      /wiki/Jim_Sensenbrenner       Jim Sensenbrenner
# 426                         /wiki/Glenn_Grothman          Glenn Grothman
# 427                             /wiki/Sean_Duffy              Sean Duffy
# 428   /wiki/Mike_Gallagher_(American_politician)          Mike Gallagher
# 429                             /wiki/Liz_Cheney              Liz Cheney
#
#                                                  party
# 0                                           Republican
# 1      New York University (BM)Samford University (JD)
# 2    Jacksonville State University (BA, MPA)Birming...
# 3    University of North AlabamaBirmingham–Southern...
# 4       Duke University (BA)University of Alabama (JD)
# 5                           University of Alabama (BS)
# 6                                           Democratic
# 7                                           Republican
# 8                                           Democratic
# 9                                           Republican
# 10                                          Democratic
# 11                                          Republican
# 12   Brigham Young University (BA)University of Ari...
# 13           Arizona State University, Tempe (BS, MBA)
# 14                                          Democratic
# 15                                          Republican
# 16                                          Democratic
# 17                                          Republican
# 18                          Vanderbilt University (BS)
# 19                       Arkansas Tech University (BA)
# 20     University of Arkansas (BS)Yale University (MS)
# 21   Butte CollegeCalifornia Polytechnic State Univ...
# 22                                          Democratic
# 23   University of California, Berkeley (BA)Harvard...
# 24                                          Republican
# 25                                          Democratic
# 26             University of California, Berkeley (BA)
# 27           University of California, Irvine (BS, MD)
# 28                                          Republican
# 29                                          Democratic
# ..                                                 ...
# 400                                         Democratic
# 401  American University (BA)University of Virginia...
# 402                                         Republican
# 403  Bates College (BA)Washington and Lee Universit...
# 404  Hope College (BA)Princeton Theological Seminar...
# 405                                         Democratic
# 406                                         Republican
# 407  Middlebury College (BA)Georgetown University (JD)
# 408                                         Democratic
# 409    Reed College (BS)University of Washington (MBA)
# 410  Pacific Lutheran University (BA)University of ...
# 411                                         Republican
# 412                   Washington State University (BS)
# 413  Pensacola Christian College (BA)University of ...
# 414                                         Democratic
# 415  Georgetown University (BA)Northwestern Univers...
# 416                                         Republican
# 417                                         Democratic
# 418  Evergreen State College (BA)Portland State Uni...
# 419                                         Republican
# 420                             Dartmouth College (BA)
# 421                                         Republican
# 422                                         Democratic
# 423  Harvard University (BA)London School of Econom...
# 424                          Marquette University (BA)
# 425                                         Republican
# 426           University of Wisconsin–Madison (BA, JD)
# 427  Saint Mary's University of Minnesota (BA)Willi...
# 428  Princeton University (BA)National Intelligence...
# 429    Colorado College (BA)University of Chicago (JD)
#
# [430 rows x 6 columns]

# %%
all_info.education
# Out:
# 0      [Duke University (BA), University of Alabama (...
# 1      [New York University (BM), Samford University ...
# 2      [Jacksonville State University (BA, MPA), Birm...
# 3      [University of North Alabama, Birmingham–South...
# 4      [Duke University (BA), University of Alabama (...
# 5                           [University of Alabama (BS)]
# 6      [Princeton University (BA), St Hilda's College...
# 7      [Yuba College, California State University, Ch...
# 8                  [Lewis University, DePaul University]
# 9      [United States Air Force Academy (BS), Harvard...
# 10                          [University of Arizona (BA)]
# 11                      [Creighton University (BS, DDS)]
# 12     [Brigham Young University (BA), University of ...
# 13           [Arizona State University, Tempe (BS, MBA)]
# 14                             [Harvard University (BA)]
# 15                [University of Wisconsin–Madison (BA)]
# 16     [Brigham Young University (BA), Arizona State ...
# 17                      [Arkansas State University (BS)]
# 18                          [Vanderbilt University (BS)]
# 19                       [Arkansas Tech University (BA)]
# 20     [University of Arkansas (BS), Yale University ...
# 21     [Butte College, California Polytechnic State U...
# 22     [University of California, Santa Barbara (BA),...
# 23     [University of California, Berkeley (BA), Harv...
# 24          [University of California, Los Angeles (BA)]
# 25     [Napa Valley College, California State Univers...
# 26             [University of California, Berkeley (BA)]
# 27           [University of California, Irvine (BS, MD)]
# 28     [Southern Connecticut State University (BS), C...
# 29     [United States Military Academy, University of...
#                              ...
# 400       [Harvard University (BA), Boston College (JD)]
# 401    [American University (BA), University of Virgi...
# 402                    [University of Richmond (BA, JD)]
# 403    [Bates College (BA), Washington and Lee Univer...
# 404    [Hope College (BA), Princeton Theological Semi...
# 405                              [Williams College (BA)]
# 406    [Emory and Henry College (BA), Washington and ...
# 407    [Middlebury College (BA), Georgetown Universit...
# 408    [Maryknoll College (BA), Harvard University (M...
# 409    [Reed College (BS), University of Washington (...
# 410    [Pacific Lutheran University (BA), University ...
# 411    [Bellevue College, University of Washington (BA)]
# 412                   [Washington State University (BS)]
# 413    [Pensacola Christian College (BA), University ...
# 414    [Princeton University (BA), University of Oxfo...
# 415    [Georgetown University (BA), Northwestern Univ...
# 416                       [Concordia University, Oregon]
# 417    [Western Washington University, Fordham Univer...
# 418    [Evergreen State College (BA), Portland State ...
# 419                             [Purdue University (BS)]
# 420                             [Dartmouth College (BA)]
# 421                              [Miami University (BA)]
# 422               [University of Wisconsin–Madison (BA)]
# 423    [Harvard University (BA), London School of Eco...
# 424                          [Marquette University (BA)]
# 425    [Stanford University (BA), University of Wisco...
# 426           [University of Wisconsin–Madison (BA, JD)]
# 427    [Saint Mary's University of Minnesota (BA), Wi...
# 428    [Princeton University (BA), National Intellige...
# 429    [Colorado College (BA), University of Chicago ...
# Name: education, Length: 430, dtype: object

# %%
def highest_education_count():
    count = 0
    for education in all_info.education:
        if len(education) > count:
            count = len(education)
    return count
highest_education_count()
# Out:
# 4

# %%
def highest_experience_count():
    count = 0
    for experience in all_info.experience:
        if len(experience) > count:
            count = len(experience)
    return count
highest_experience_count()
# Out:
# 4

# %%
all_info.to_csv(SAVED_CSV_FILE_PATH, index=False)

# %%
# to get lists back
converters = {'experience':ast.literal_eval, 'education':ast.literal_eval}
data = pd.read_csv(SAVED_CSV_FILE_PATH, converters=converters)
data
# Out:
#              district                                          education  \
# 0           Alabama 1  [Duke University (BA), University of Alabama (...
# 1           Alabama 2  [New York University (BM), Samford University ...
# 2           Alabama 3  [Jacksonville State University (BA, MPA), Birm...
# 3           Alabama 4  [University of North Alabama, Birmingham–South...
# 4           Alabama 5  [Duke University (BA), University of Alabama (...
# 5           Alabama 6                       [University of Alabama (BS)]
# 6           Alabama 7  [Princeton University (BA), St Hilda's College...
# 7     Alaska at large  [Yuba College, California State University, Ch...
# 8           Arizona 1              [Lewis University, DePaul University]
# 9           Arizona 2  [United States Air Force Academy (BS), Harvard...
# 10          Arizona 3                       [University of Arizona (BA)]
# 11          Arizona 4                   [Creighton University (BS, DDS)]
# 12          Arizona 5  [Brigham Young University (BA), University of ...
# 13          Arizona 6        [Arizona State University, Tempe (BS, MBA)]
# 14          Arizona 7                          [Harvard University (BA)]
# 15          Arizona 8             [University of Wisconsin–Madison (BA)]
# 16          Arizona 9  [Brigham Young University (BA), Arizona State ...
# 17         Arkansas 1                   [Arkansas State University (BS)]
# 18         Arkansas 2                       [Vanderbilt University (BS)]
# 19         Arkansas 3                    [Arkansas Tech University (BA)]
# 20         Arkansas 4  [University of Arkansas (BS), Yale University ...
# 21       California 1  [Butte College, California Polytechnic State U...
# 22       California 2  [University of California, Santa Barbara (BA),...
# 23       California 3  [University of California, Berkeley (BA), Harv...
# 24       California 4       [University of California, Los Angeles (BA)]
# 25       California 5  [Napa Valley College, California State Univers...
# 26       California 6          [University of California, Berkeley (BA)]
# 27       California 7        [University of California, Irvine (BS, MD)]
# 28       California 8  [Southern Connecticut State University (BS), C...
# 29       California 9  [United States Military Academy, University of...
# ..                ...                                                ...
# 400        Virginia 3     [Harvard University (BA), Boston College (JD)]
# 401        Virginia 4  [American University (BA), University of Virgi...
# 402        Virginia 5                  [University of Richmond (BA, JD)]
# 403        Virginia 6  [Bates College (BA), Washington and Lee Univer...
# 404        Virginia 7  [Hope College (BA), Princeton Theological Semi...
# 405        Virginia 8                            [Williams College (BA)]
# 406        Virginia 9  [Emory and Henry College (BA), Washington and ...
# 407       Virginia 10  [Middlebury College (BA), Georgetown Universit...
# 408       Virginia 11  [Maryknoll College (BA), Harvard University (M...
# 409      Washington 1  [Reed College (BS), University of Washington (...
# 410      Washington 2  [Pacific Lutheran University (BA), University ...
# 411      Washington 3  [Bellevue College, University of Washington (BA)]
# 412      Washington 4                 [Washington State University (BS)]
# 413      Washington 5  [Pensacola Christian College (BA), University ...
# 414      Washington 6  [Princeton University (BA), University of Oxfo...
# 415      Washington 7  [Georgetown University (BA), Northwestern Univ...
# 416      Washington 8                     [Concordia University, Oregon]
# 417      Washington 9  [Western Washington University, Fordham Univer...
# 418     Washington 10  [Evergreen State College (BA), Portland State ...
# 419   West Virginia 1                           [Purdue University (BS)]
# 420   West Virginia 2                           [Dartmouth College (BA)]
# 421       Wisconsin 1                            [Miami University (BA)]
# 422       Wisconsin 2             [University of Wisconsin–Madison (BA)]
# 423       Wisconsin 3  [Harvard University (BA), London School of Eco...
# 424       Wisconsin 4                        [Marquette University (BA)]
# 425       Wisconsin 5  [Stanford University (BA), University of Wisco...
# 426       Wisconsin 6         [University of Wisconsin–Madison (BA, JD)]
# 427       Wisconsin 7  [Saint Mary's University of Minnesota (BA), Wi...
# 428       Wisconsin 8  [Princeton University (BA), National Intellige...
# 429  Wyoming at large  [Colorado College (BA), University of Chicago ...
#
#                                             experience  \
# 0    [Alabama Senate, Alabama State Board of Educat...
# 1                            [Montgomery City Council]
# 2    [Calhoun County Commissioner, Alabama House of...
# 3                         [Haleyville Municipal Judge]
# 4    [Alabama House of Representatives, Madison Cou...
# 5                                     [Policy analyst]
# 6                                           [Attorney]
# 7    [Alaska Senate, Ship captain, Mayor of Fort Yu...
# 8                                     [Arizona Senate]
# 9                                       [USAF Colonel]
# 10                  [Pima County Board of Supervisors]
# 11   [President of the Northern Arizona Dental Soci...
# 12                                    [Arizona Senate]
# 13   [Arizona House of Representatives, Arizona Boa...
# 14                  [Arizona House of Representatives]
# 15   [Arizona House of Representatives, Arizona Sen...
# 16   [Arizona Senate, Arizona House of Representati...
# 17                          [Broadcaster, businessman]
# 18                                       [Businessman]
# 19                         [Mayor of Rogers, Arkansas]
# 20                 [Arkansas House of Representatives]
# 21   [California State Senate, California State Ass...
# 22                         [California State Assembly]
# 23   [United States Deputy Secretary of the Interio...
# 24      [California Senate, California State Assembly]
# 25                           [California State Senate]
# 26               [Sacramento, California City Council]
# 27   [Chief Medical Officer of Sacramento County, C...
# 28                         [California State Assembly]
# 29                             [Engineering executive]
# ..                                                 ...
# 400     [Virginia Senate, Virginia House of Delegates]
# 401     [Virginia Senate, Virginia House of Delegates]
# 402                                  [Virginia Senate]
# 403                           [Private legal practice]
# 404    [Economics professor at Randolph–Macon College]
# 405  [U.S. Ambassador to Switzerland and Liechtenst...
# 406  [Majority Leader of the Virginia House of Dele...
# 407                      [Virginia House of Delegates]
# 408        [Fairfax County Board of Supervisors Chair]
# 409        [Washington Department of Revenue Director]
# 410                         [Snohomish County Council]
# 411              [Washington House of Representatives]
# 412              [Washington House of Representatives]
# 413              [Washington House of Representatives]
# 414                          [Washington State Senate]
# 415                          [Washington State Senate]
# 416                              [King County Sheriff]
# 417                          [Washington State Senate]
# 418              [Washington House of Representatives]
# 419    [West Virginia House of Delegates, businessman]
# 420                                  [Maryland Senate]
# 421                             [Legislative Director]
# 422                         [Wisconsin State Assembly]
# 423                                [County Prosecutor]
# 424  [Wisconsin State Senate, Wisconsin State Assem...
# 425  [Wisconsin State Senate, Wisconsin State Assem...
# 426       [Wisconsin Senate, Wisconsin State Assembly]
# 427                 [Ashland County District Attorney]
# 428                                [Political advisor]
# 429  [Principal Deputy Assistant Secretary of State...
#
#                                             link                    name  \
# 0                            /wiki/Bradley_Byrne           Bradley Byrne
# 1                              /wiki/Martha_Roby             Martha Roby
# 2         /wiki/Mike_Rogers_(Alabama_politician)             Mike Rogers
# 3                          /wiki/Robert_Aderholt         Robert Aderholt
# 4                                /wiki/Mo_Brooks               Mo Brooks
# 5                 /wiki/Gary_Palmer_(politician)             Gary Palmer
# 6                             /wiki/Terri_Sewell            Terri Sewell
# 7                                /wiki/Don_Young               Don Young
# 8                         /wiki/Tom_O%27Halleran          Tom O'Halleran
# 9                           /wiki/Martha_McSally          Martha McSally
# 10                      /wiki/Ra%C3%BAl_Grijalva           Raúl Grijalva
# 11                              /wiki/Paul_Gosar              Paul Gosar
# 12                              /wiki/Andy_Biggs              Andy Biggs
# 13                        /wiki/David_Schweikert        David Schweikert
# 14                           /wiki/Ruben_Gallego           Ruben Gallego
# 15                            /wiki/Debbie_Lesko            Debbie Lesko
# 16                          /wiki/Kyrsten_Sinema          Kyrsten Sinema
# 17              /wiki/Rick_Crawford_(politician)           Rick Crawford
# 18                /wiki/French_Hill_(politician)             French Hill
# 19                            /wiki/Steve_Womack            Steve Womack
# 20                         /wiki/Bruce_Westerman         Bruce Westerman
# 21                            /wiki/Doug_LaMalfa            Doug LaMalfa
# 22                           /wiki/Jared_Huffman           Jared Huffman
# 23                          /wiki/John_Garamendi          John Garamendi
# 24                          /wiki/Tom_McClintock          Tom McClintock
# 25   /wiki/Mike_Thompson_(California_politician)           Mike Thompson
# 26                            /wiki/Doris_Matsui            Doris Matsui
# 27                                /wiki/Ami_Bera                Ami Bera
# 28                  /wiki/Paul_Cook_(politician)               Paul Cook
# 29                          /wiki/Jerry_McNerney          Jerry McNerney
# ..                                           ...                     ...
# 400               /wiki/Bobby_Scott_(politician)             Bobby Scott
# 401                        /wiki/Donald_McEachin         Donald McEachin
# 402                        /wiki/Tom_Garrett_Jr.         Tom Garrett Jr.
# 403                          /wiki/Bob_Goodlatte           Bob Goodlatte
# 404                              /wiki/Dave_Brat               Dave Brat
# 405                              /wiki/Don_Beyer               Don Beyer
# 406                        /wiki/Morgan_Griffith         Morgan Griffith
# 407                       /wiki/Barbara_Comstock        Barbara Comstock
# 408                         /wiki/Gerry_Connolly          Gerry Connolly
# 409                          /wiki/Suzan_DelBene           Suzan DelBene
# 410                            /wiki/Rick_Larsen             Rick Larsen
# 411                  /wiki/Jaime_Herrera_Beutler   Jaime Herrera Beutler
# 412                           /wiki/Dan_Newhouse            Dan Newhouse
# 413                 /wiki/Cathy_McMorris_Rodgers  Cathy McMorris Rodgers
# 414                           /wiki/Derek_Kilmer            Derek Kilmer
# 415                        /wiki/Pramila_Jayapal         Pramila Jayapal
# 416                          /wiki/Dave_Reichert           Dave Reichert
# 417                /wiki/Adam_Smith_(politician)              Adam Smith
# 418                            /wiki/Dennis_Heck             Dennis Heck
# 419                         /wiki/David_McKinley          David McKinley
# 420                            /wiki/Alex_Mooney             Alex Mooney
# 421                              /wiki/Paul_Ryan               Paul Ryan
# 422                             /wiki/Mark_Pocan              Mark Pocan
# 423                               /wiki/Ron_Kind                Ron Kind
# 424                             /wiki/Gwen_Moore              Gwen Moore
# 425                      /wiki/Jim_Sensenbrenner       Jim Sensenbrenner
# 426                         /wiki/Glenn_Grothman          Glenn Grothman
# 427                             /wiki/Sean_Duffy              Sean Duffy
# 428   /wiki/Mike_Gallagher_(American_politician)          Mike Gallagher
# 429                             /wiki/Liz_Cheney              Liz Cheney
#
#                                                  party
# 0                                           Republican
# 1      New York University (BM)Samford University (JD)
# 2    Jacksonville State University (BA, MPA)Birming...
# 3    University of North AlabamaBirmingham–Southern...
# 4       Duke University (BA)University of Alabama (JD)
# 5                           University of Alabama (BS)
# 6                                           Democratic
# 7                                           Republican
# 8                                           Democratic
# 9                                           Republican
# 10                                          Democratic
# 11                                          Republican
# 12   Brigham Young University (BA)University of Ari...
# 13           Arizona State University, Tempe (BS, MBA)
# 14                                          Democratic
# 15                                          Republican
# 16                                          Democratic
# 17                                          Republican
# 18                          Vanderbilt University (BS)
# 19                       Arkansas Tech University (BA)
# 20     University of Arkansas (BS)Yale University (MS)
# 21   Butte CollegeCalifornia Polytechnic State Univ...
# 22                                          Democratic
# 23   University of California, Berkeley (BA)Harvard...
# 24                                          Republican
# 25                                          Democratic
# 26             University of California, Berkeley (BA)
# 27           University of California, Irvine (BS, MD)
# 28                                          Republican
# 29                                          Democratic
# ..                                                 ...
# 400                                         Democratic
# 401  American University (BA)University of Virginia...
# 402                                         Republican
# 403  Bates College (BA)Washington and Lee Universit...
# 404  Hope College (BA)Princeton Theological Seminar...
# 405                                         Democratic
# 406                                         Republican
# 407  Middlebury College (BA)Georgetown University (JD)
# 408                                         Democratic
# 409    Reed College (BS)University of Washington (MBA)
# 410  Pacific Lutheran University (BA)University of ...
# 411                                         Republican
# 412                   Washington State University (BS)
# 413  Pensacola Christian College (BA)University of ...
# 414                                         Democratic
# 415  Georgetown University (BA)Northwestern Univers...
# 416                                         Republican
# 417                                         Democratic
# 418  Evergreen State College (BA)Portland State Uni...
# 419                                         Republican
# 420                             Dartmouth College (BA)
# 421                                         Republican
# 422                                         Democratic
# 423  Harvard University (BA)London School of Econom...
# 424                          Marquette University (BA)
# 425                                         Republican
# 426           University of Wisconsin–Madison (BA, JD)
# 427  Saint Mary's University of Minnesota (BA)Willi...
# 428  Princeton University (BA)National Intelligence...
# 429    Colorado College (BA)University of Chicago (JD)
#
# [430 rows x 6 columns]
